# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

from model import predict
from preprocess import preprocess_input

data = {"age": 35, "bmi": 23.5}
features = preprocess_input(data)
result = predict(features)
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 10
#       8 data = {"age": 35, "bmi": 23.5}
#       9 features = preprocess_input(data)
# ---> 10 result = predict(features)
#      11 print(result)
#
# File C:\Work\Lung-Cancer-Prediction\ML\app\model.py:19, in predict(features)
#      18 def predict(features: list[float]) -> dict:
# ---> 19     model = load_model()
#      20     prob = model.predict_proba([features])[0][1]
#      21     result = "positive" if prob >= THRESHOLD else "negative"
#
# File C:\Work\Lung-Cancer-Prediction\ML\app\model.py:15, in load_model()
#      13 global _model
#      14 if _model is None:
# ---> 15     _model = joblib.load(MODEL_PATH)
#      16 return _model
#
# File C:\Work\Lung-Cancer-Prediction\ML\venv\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
# ...
